# %%
path_prefix = "abfss://data@kaniniproraw.dfs.core.windows.net/"
account_key = ""
spark.conf.set("fs.azure.account.key.kaniniproraw.dfs.core.windows.net",account_key)

# %%
catalog = "kaninipro_catalog"
database = "dev"
catalog_database=catalog+"."+database
