# %%
# %run ../config

# %%
from pyspark.sql.functions import max, col,current_timestamp, to_date

# %%
spark.sql(f"CREATE DATABASE IF NOT EXISTS {catalog_database}")

# %%
sensor_data_path = f'{path_prefix}/sensor_data'

# %%
read_df = spark.read.format("parquet").load(sensor_data_path)\
                .withColumn("__insert_time",current_timestamp())

read_df.write.mode("overwrite").partitionBy("loaded_dt").format("delta").saveAsTable(silver_tbl_name)
